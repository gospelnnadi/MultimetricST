# %%
# !sbatch --partition=medium --nodelist=node014 --mem-per-cpu=400G  --output=outputs/test_multimetricST_mode1.log slurm_exec_mmst.sh Data/DLPFC/151673 Data/DLPFC/151673/metadata.tsv

# %%
# !sbatch --partition=medium --nodelist=node015 --mem-per-cpu=400G  --output=outputs/test_multimetricST_mode1.log slurm_exec_mmst.sh Data/DLPFC/151673 Data/DLPFC/151673/metadata.tsv 1 0 STAGATE SpaceFlow multimetricST_outputs/clustering_results.csv

# %%
# !sbatch --partition=medium --nodelist=node015 --mem-per-cpu=400G  --output=outputs/test_multimetricST_mode1.log slurm_exec_mmst.sh Data/DLPFC/151673 Data/DLPFC/151673/metadata.tsv 3 0 STAGATE SpaceFlow multimetricST_outputs/clustering_results.csv

# %%
# !bash slurm_exec_mmst.sh Data/Preprocessed/151673.h5ad Data/DLPFC/151673/metadata.tsv 3 1 STAGATE SpaceFlow multimetricST_outputs/clustering_results.csv > outputs/test_multimetricST_mode2.log &

# %%
bash slurm_exec_mmst.sh Data/DLPFC/151673 Data/DLPFC/151673/metadata.tsv 1 0 STAGATE SpaceFlow multimetricST_outputs/clustering_results.csv > outputs/test_multimetricST_mode2.log &
