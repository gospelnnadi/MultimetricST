# %% [markdown]
# # Evaluating Simulated Datasets with of various clusters configurations

# %%
# !wget https://zenodo.org/records/19153414/files/SRTsim-SyntheticData.zip
# !unzip SRTsim-SyntheticData.zip -d Data/
# !rm SRTsim-SyntheticData.zip
# Out:
# --2026-03-21 20:22:07--  https://zenodo.org/records/19056154/files/SRTsim-SyntheticData.zip
# Resolving zenodo.org (zenodo.org)... 188.184.98.114, 137.138.153.219, 188.185.48.75, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 703677 (687K) [application/octet-stream]
# Saving to: ‘SRTsim-SyntheticData.zip’
#
# SRTsim-SyntheticDat 100%[===================>] 687.18K  --.-KB/s    in 0.08s
#
# 2026-03-21 20:22:08 (8.34 MB/s) - ‘SRTsim-SyntheticData.zip’ saved [703677/703677]
#
# Archive:  SRTsim-SyntheticData.zip
#    creating: Data1/SRTsim-SyntheticData/
#   inflating: Data1/SRTsim-SyntheticData/SRTsim_synthetic1.h5ad
#   inflating: Data1/SRTsim-SyntheticData/SRTsim_synthetic2.h5ad

# %%
results=[]

# %%
import scanpy as sc
import os
from MultimetricST import preprocess, plot_label
from Evaluate.evaluate import evaluate_cluster
plot_size=0.02
adata= sc.read_h5ad("Data/SRTsim-SyntheticData/SRTsim_synthetic1.h5ad")
pca_matrix = None
plot_savepath=f"multimetricST_outputs/figures/Simulated_Dataset"
os.makedirs(plot_savepath, exist_ok=True)
print(adata)
ground_truth= adata.obs["ground_truth"].values

method="Case1"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case2"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case3"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case4"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case5"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case6"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case7"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case8"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)

method="Case9"
print(f"\nEvaluating {method} cluster plot and saving to {plot_savepath}/{method}\n")
pred=adata.obs[method]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
scores=evaluate_cluster( adata,pred, ground_truth, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)
# Out:
# AnnData object with n_obs × n_vars = 2025 × 850
#     obs: 'ground_truth', 'Case1', 'Case2', 'Case3', 'Case4', 'Case5', 'Case6', 'Case7', 'Case8', 'Case9'
#     uns: 'average_penalty'
#     obsm: 'spatial', 'spatial_neigh'
#
# Evaluating Case1 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case1
#
# Evaluation runtime: 1.6554 seconds
# Evaluation Current memory usage: 4.1133 MB
# Evaluation Peak memory usage: 66.2386 MB
# ARI:  0.4998
# AMI:  0.6664
# Purity Score:  0.5111
# Homogeneity Score:  0.5
# Completeness Score:  1.0
# V-Measure Score:  0.6667
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.0
# ASW:  0.353
#
# Evaluating Case2 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case2
#
# Evaluation runtime: 1.5918 seconds
# Evaluation Current memory usage: 4.1158 MB
# Evaluation Peak memory usage: 66.2737 MB
# ARI:  0.5285
# AMI:  0.6609
# Purity Score:  0.8257
# Homogeneity Score:  0.7582
# Completeness Score:  0.587
# V-Measure Score:  0.6617
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.004
# ASW:  0.348
#
# Evaluating Case3 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case3
#
# Evaluation runtime: 1.5819 seconds
# Evaluation Current memory usage: 4.1156 MB
# Evaluation Peak memory usage: 66.2895 MB
# ARI:  0.5314
# AMI:  0.7022
# Purity Score:  0.956
# Homogeneity Score:  0.8788
# Completeness Score:  0.586
# V-Measure Score:  0.7031
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.0059
# ASW:  0.2859
#
# Evaluating Case4 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case4
#
# Evaluation runtime: 1.5344 seconds
# Evaluation Current memory usage: 4.1170 MB
# Evaluation Peak memory usage: 66.3205 MB
# ARI:  0.3012
# AMI:  0.549
# Purity Score:  0.8257
# Homogeneity Score:  0.769
# Completeness Score:  0.4292
# V-Measure Score:  0.5509
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.0089
# ASW:  0.3343
#
# Evaluating Case5 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case5
#
# Evaluation runtime: 1.5803 seconds
# Evaluation Current memory usage: 4.1123 MB
# Evaluation Peak memory usage: 66.2539 MB
# ARI:  0.5434
# AMI:  0.6906
# Purity Score:  0.7556
# Homogeneity Score:  0.6599
# Completeness Score:  0.7254
# V-Measure Score:  0.6911
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.001
# ASW:  0.2969
#
# Evaluating Case6 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case6
#
# Evaluation runtime: 1.5557 seconds
# Evaluation Current memory usage: 4.1168 MB
# Evaluation Peak memory usage: 66.3544 MB
# ARI:  0.296
# AMI:  0.5919
# Purity Score:  0.956
# Homogeneity Score:  0.8911
# Completeness Score:  0.4456
# V-Measure Score:  0.5941
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.0104
# ASW:  0.3406
#
# Evaluating Case7 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case7
#
# Evaluation runtime: 1.5948 seconds
# Evaluation Current memory usage: 4.1150 MB
# Evaluation Peak memory usage: 66.3209 MB
# ARI:  -0.0018
# AMI:  -0.0043
# Purity Score:  0.2612
# Homogeneity Score:  0.0001
# Completeness Score:  0.0001
# V-Measure Score:  0.0001
# Silhouette Spatial Coefficient:  0.0
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.7299
# ASW:  -0.0719
#
# Evaluating Case8 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case8
#
# Evaluation runtime: 1.6081 seconds
# Evaluation Current memory usage: 4.1129 MB
# Evaluation Peak memory usage: 66.2704 MB
# ARI:  0.1893
# AMI:  0.3022
# Purity Score:  0.5081
# Homogeneity Score:  0.3469
# Completeness Score:  0.2702
# V-Measure Score:  0.3038
# Silhouette Spatial Coefficient:  -0.0689
# SSC average dispersion: 0.082
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.6999
# PAS:  0.0148
# ASW:  -0.0492
#
# Evaluating Case9 cluster plot and saving to multimetricST_outputs/figures/Simulated_Dataset/Case9
#
# Evaluation runtime: 1.5766 seconds
# Evaluation Current memory usage: 4.1121 MB
# Evaluation Peak memory usage: 66.2539 MB
# ARI:  0.8081
# AMI:  0.784
# Purity Score:  0.9235
# Homogeneity Score:  0.7843
# Completeness Score:  0.7843
# V-Measure Score:  0.7843
# Silhouette Spatial Coefficient:  -0.0598
# SSC average dispersion: 0.064
# Silhouette Coefficient:  0.0
# Davies Bouldin Index:  0.0
# CHAOS:  7.9625
# PAS:  0.0316
# ASW:  0.3581

# %% [markdown]
# # Evalutaion Simulated dataset using Silhouette spatial coefficient

# %%
import scanpy as sc
import numpy as np
import os
from MultimetricST import preprocess, plot_label
from Evaluate.evaluate import evaluate_cluster
plot_size=0.02
adata= sc.read_h5ad("Data/SRTsim-SyntheticData/SRTsim_synthetic2.h5ad")
pca_matrix = adata.obsm["X_pca"]
plot_savepath=f"multimetricST_outputs/figures/Simulated_Dataset"
os.makedirs(plot_savepath, exist_ok=True)
print(adata)

method="Case10"
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}" )
pred=adata.obs[method]
scores=evaluate_cluster( adata,pred, None, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)
#perm
print("\nPermuting spatial coordinates...\n")

n = adata.obsm['spatial'].shape[0]
rng = np.random.default_rng(seed=43)
perm = rng.choice(n, size=n, replace=False)
adata.obsm['spatial'] = adata.obsm['spatial'][perm]
plot_label(adata, plot_size=plot_size, key=method, savepath=f"{plot_savepath}/{method}_perm" )
pred=adata.obs[method]
scores=evaluate_cluster( adata,pred, None, pca_matrix, is_visium=False,verbose=True,decimal=4)
m={'method':method}
m.update(scores)
results.append(m)
# Out:
# AnnData object with n_obs × n_vars = 1024 × 200
#     obs: 'Case10'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'average_penalty', 'hvg', 'log1p'
#     obsm: 'X_pca', 'spatial', 'spatial_neigh'
# Evaluation runtime: 0.6146 seconds
# Evaluation Current memory usage: 1.0581 MB
# Evaluation Peak memory usage: 13.6369 MB
# ARI:  None
# AMI:  None
# Purity Score:  None
# Homogeneity Score:  None
# Completeness Score:  None
# V-Measure Score:  None
# Silhouette Spatial Coefficient:  0.7534
# SSC average dispersion: 0.0
# Silhouette Coefficient:  0.7534
# Davies Bouldin Index:  0.8197
# CHAOS:  10.8306
# PAS:  0.0
# ASW:  0.3527
#
# Permuting spatial coordinates...
#
# Evaluation runtime: 0.5978 seconds
# Evaluation Current memory usage: 1.0592 MB
# Evaluation Peak memory usage: 13.6380 MB
# ARI:  None
# AMI:  None
# Purity Score:  None
# Homogeneity Score:  None
# Completeness Score:  None
# V-Measure Score:  None
# Silhouette Spatial Coefficient:  0.558
# SSC average dispersion: 0.7928
# Silhouette Coefficient:  0.7534
# Davies Bouldin Index:  0.8197
# CHAOS:  11.1999
# PAS:  0.3457
# ASW:  -0.0006

# %%
import pandas as pd
results_df = pd.DataFrame(results).round(4)
os.makedirs(plot_savepath, exist_ok=True)
os.makedirs("multimetricST_outputs", exist_ok=True)
result_savepath=f"multimetricST_outputs/cluster_result_simulated_dataset.csv"
results_df.to_csv(result_savepath,  index=False)

# %% [markdown]
# # Launch Dashboard

# %%
# !python MultimetricST.py --mode 3 --result_filename cluster_result_simulated_dataset.csv  --data_name Simulated_Dataset
# Out:
# /home/accounts/personale/nndgpl46/miniconda3/envs/MMST/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# The current working dir is,  /storage-large/homedirs/nndgpl46/MultimetricST
# Warning: --data_path or --spatial_path not provided. Spatial visualization will be skipped in Mode 3.
# adata_raw dim (0, 0)
# Warning: Ground truth annotation not found in provided path or adata.obs. External metrics will be set to 0.
# Running Mode 3: Visualization from precomputed scores
# Using method_cluster_label from precomputed results for visualization
#  show methods_cluster_label  ['Case1', 'Case2', 'Case3', 'Case4', 'Case5', 'Case6', 'Case7', 'Case8', 'Case9', 'Case10', 'Case10']
# Saving Case1 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case1 not found in adata.obs. Skipping plot.
# Saving Case2 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case2 not found in adata.obs. Skipping plot.
# Saving Case3 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case3 not found in adata.obs. Skipping plot.
# Saving Case4 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case4 not found in adata.obs. Skipping plot.
# Saving Case5 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case5 not found in adata.obs. Skipping plot.
# Saving Case6 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case6 not found in adata.obs. Skipping plot.
# Saving Case7 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case7 not found in adata.obs. Skipping plot.
# Saving Case8 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case8 not found in adata.obs. Skipping plot.
# Saving Case9 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case9 not found in adata.obs. Skipping plot.
# Saving Case10 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case10 not found in adata.obs. Skipping plot.
# Saving Case10 cluster plot to /storage-large/homedirs/nndgpl46/MultimetricST/multimetricST_outputs/figures/Simulated_Dataset/
# Warning: Method Case10 not found in adata.obs. Skipping plot.
# Running dashboard visualization...
# Port 8008 is now free.
# Port free? False
# Launching dashboard...
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# Launching server at http://0.0.0.0:8008
# Launching server at http://localhost:8008
# Visualization completed.
# ^C
